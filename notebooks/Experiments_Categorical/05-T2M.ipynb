# %%
# %load_ext autoreload
# %autoreload 2

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch
import pandas as pd
if torch.cuda.is_available():
    device = torch.device("cuda") 
else:
    device = torch.device("cpu")

# %%
from src.dataloader import *
from src.models import *
from src.trainer import *
from src.utils import *

# %%
DATADRIVE = '/datadrive_ssd/'

# %%
interval=0.75
cat_bins = np.arange(0, interval*128, interval)
len(cat_bins), max(cat_bins)
# Out:
# (128, 95.25)

# %% [markdown]
# ## Load data

# %%
ds_train = TiggeMRMSDataset(
    tigge_dir=f'{DATADRIVE}/tigge/32km/',
    tigge_vars=['total_precipitation', '2m_temperature'],
    mrms_dir=f'{DATADRIVE}/mrms/4km/RadarOnly_QPE_06H/',
    rq_fn=f'{DATADRIVE}/mrms/4km/RadarQuality.nc',
    const_fn=f'{DATADRIVE}/tigge/32km/constants.nc',
    const_vars=['orog', 'lsm'],
    data_period=('2018-01', '2019-12'),
    val_days=5,
    cat_bins=cat_bins,
    split='train',
    tp_log=1
)
# Out:
# /anaconda/envs/nwp-downscale/lib/python3.8/site-packages/xarray/core/indexing.py:1369: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# Loading data

# %%
ds_valid = TiggeMRMSDataset(
    tigge_dir=f'{DATADRIVE}/tigge/32km/',
    tigge_vars=['total_precipitation', '2m_temperature'],
    mrms_dir=f'{DATADRIVE}/mrms/4km/RadarOnly_QPE_06H/',
    rq_fn=f'{DATADRIVE}/mrms/4km/RadarQuality.nc',
    const_fn=f'{DATADRIVE}/tigge/32km/constants.nc',
    const_vars=['orog', 'lsm'],
    data_period=('2018-01', '2019-12'),
    val_days=5,
    cat_bins=cat_bins,
    split='valid',
    tp_log=1,
    mins=ds_train.mins,
    maxs=ds_train.maxs
)
# Out:
# /anaconda/envs/nwp-downscale/lib/python3.8/site-packages/xarray/core/indexing.py:1369: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# Loading data

# %%
sampler_train = torch.utils.data.WeightedRandomSampler(ds_train.compute_weights(
    threshold=interval
), len(ds_train))
sampler_valid = torch.utils.data.WeightedRandomSampler(ds_valid.compute_weights(
    threshold=interval
), len(ds_valid))

# %%
dl_train = torch.utils.data.DataLoader(ds_train, batch_size=16, sampler=sampler_train)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=16, sampler=sampler_valid)

# %%
X, y = next(iter(dl_train))
X.shape, y.shape
# Out:
# (torch.Size([16, 4, 16, 16]), torch.Size([16, 128, 128]))

# %% [markdown]
# ## Model

# %%
ds_train.input_vars
# Out:
# 4

# %%
gen = Generator(
    nres=3, nf_in=ds_train.input_vars, nf=256, nout=128, activation_out=None, use_noise=False,
    spectral_norm=False, halve_filters_up=False, batch_norm=True
).to(device)

# %%
count_parameters(gen)
# Out:
# 7391616

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(gen.parameters(), lr=1e-5)

# %%
X, y = next(iter(dl_train))
X.shape, y.shape
# Out:
# (torch.Size([16, 4, 16, 16]), torch.Size([16, 128, 128]))

# %%
fig, axs = plt.subplots(2, 8, figsize=(24, 12))
for x, ax in zip(X.numpy(), axs.flat):
    I = ax.imshow(x[0], cmap='gist_ncar_r')
    plt.colorbar(I, ax=ax, orientation='horizontal')

# %%
fig, axs = plt.subplots(2, 8, figsize=(24, 12))
for x, ax in zip(y.numpy(), axs.flat):
    I = ax.imshow(x, cmap='gist_ncar_r')
    plt.colorbar(I, ax=ax, orientation='horizontal')

# %%
for i, (X, y) in enumerate(ds_train):
    if y.min() < 0:
        break

# %%
i
# Out:
# 180

# %%
trainer = Trainer(gen, optimizer, criterion, dl_train, dl_valid)

# %%
trainer.fit(5)
# Out:
# HBox(children=(HTML(value='Epoch 1'), FloatProgress(value=0.0, max=2680.0), HTML(value='')))
# /anaconda/envs/nwp-downscale/lib/python3.8/site-packages/torch/nn/functional.py:2503: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn("Default upsampling behavior when mode={} is changed "
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-29d1f70228dd> in <module>
# ----> 1 trainer.fit(5)
#
# ~/nwp-downscale/notebooks/Experiments_Categorical/src/trainer.py in fit(self, epochs)
#      49
#      50                 prog_bar.update()
# ---> 51                 train_loss += (loss.cpu().detach().numpy() - train_loss) / (i+1)
#      52                 prog_bar.set_postfix({'train_loss': train_loss})
#      53             self.train_losses.append(train_loss)
#
# KeyboardInterrupt:

# %%
trainer.plot_losses()

# %%
import pickle
with open('05.trainer', 'wb') as f:
    pickle.dump(trainer, f)

# %%
import pickle
with open('05.trainer', 'rb') as f:
    trainer = pickle.load(f)

# %%
trainer.plot_losses()

# %%
X, y = next(iter(dl_train))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-41dba8a2abc3> in <module>
# ----> 1 X, y = next(iter(dl_train))
#
# NameError: name 'dl_train' is not defined

# %%
preds = nn.functional.softmax(trainer.model(X.to(device)), dim=1).cpu().detach().numpy()

# %%
preds.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-29d7a5a435d2> in <module>
# ----> 1 preds.shape
#
# NameError: name 'preds' is not defined

# %%
target = y.cpu().detach().numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-dc9ca9571f00> in <module>
# ----> 1 target = y.cpu().detach().numpy()
#
# NameError: name 'y' is not defined

# %%
np.argmax(target.mean((1, 2)))
# Out:
# 3

# %%
i=7
j, k = 20, 40
plt.imshow(target[i])
plt.colorbar()
plt.scatter(j, k, c='r')

# %%
plt.imshow(X[i, 0] * ds_train.maxs.tp.values)
plt.colorbar();

# %%
plt.imshow(np.argmax(preds[i], axis=0))
plt.colorbar()

# %%
plt.plot(preds[i, :, j, k])
plt.axvline(target[i, j, k])
