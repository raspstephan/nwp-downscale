# %%
# %load_ext autoreload
# %autoreload 2

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch
if torch.cuda.is_available():
    device = torch.device("cuda") 
else:
    device = torch.device("cpu")

# %%
from src.dataloader import *
from src.models import *
from src.trainer import *
from src.utils import *
from src.layers import *

# %% [markdown]
# ## Data

# %%
DATADRIVE = '/datadrive_ssd/'

# %%
ds_train = TiggeMRMSDataset(
    tigge_dir=f'{DATADRIVE}/tigge/32km/',
    tigge_vars=['total_precipitation'],
    mrms_dir=f'{DATADRIVE}/mrms/4km/RadarOnly_QPE_06H/',
    rq_fn=f'{DATADRIVE}/mrms/4km/RadarQuality.nc',
    data_period=('2018-01', '2018-12'),
    val_days=5,
    split='train',
    tp_log=1e-1,
    pure_sr_ratio=8
)
# Out:
# /anaconda/envs/nwp-downscale/lib/python3.8/site-packages/xarray/core/indexing.py:1369: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# Loading data

# %%
ds_valid = TiggeMRMSDataset(
    tigge_dir=f'{DATADRIVE}/tigge/32km/',
    tigge_vars=['total_precipitation'],
    mrms_dir=f'{DATADRIVE}/mrms/4km/RadarOnly_QPE_06H/',
    rq_fn=f'{DATADRIVE}/mrms/4km/RadarQuality.nc',
    data_period=('2018-01', '2018-12'),
    val_days=5,
    split='valid',
    tp_log=1e-1,
    pure_sr_ratio=8
)
# Out:
# /anaconda/envs/nwp-downscale/lib/python3.8/site-packages/xarray/core/indexing.py:1369: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# Loading data

# %%
sampler_train = torch.utils.data.WeightedRandomSampler(ds_train.compute_weights(), len(ds_train))
sampler_valid = torch.utils.data.WeightedRandomSampler(ds_valid.compute_weights(), len(ds_valid))

# %%
dl_train = torch.utils.data.DataLoader(ds_train, batch_size=32, sampler=sampler_train)
dl_valid = torch.utils.data.DataLoader(ds_valid, batch_size=32, sampler=sampler_valid)

# %%
len(ds_train), len(dl_train)
# Out:
# (20988, 656)

# %%
X, y = ds_train[0]

# %%
plt.imshow(X[0])

# %%
plt.imshow(y[0])

# %% [markdown]
# ## Leinonen-like architecture

# %%
gen = Generator(
    nres=3, nf_in=1, nf=256, use_noise=True, spectral_norm=True
).to(device)

# %%
disc = Discriminator(
    nf=256, ndown=4, nres=3, sigmoid=False, spectral_norm=True
).to(device)

# %%
count_parameters(gen)/1e6, count_parameters(disc)/1e6
# Out:
# (4.167607, 4.789025)

# %%
betas = (0.5, 0.9)
disc_optimizer = torch.optim.Adam(disc.parameters(), lr=1e-4, betas=betas)
gen_optimizer = torch.optim.Adam(gen.parameters(), lr=1e-4, betas=betas)

# %%
X_sample, y_sample = next(iter(dl_train))

# %%
plot_sample(X_sample, y_sample, gen, 0)

# %% [markdown]
# ## Pretraining

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(gen.parameters(), lr=1e-4)

# %%
trainer = Trainer(gen, optimizer, criterion, dl_train, dl_valid)

# %%
trainer.fit(1)
# Out:
# HBox(children=(HTML(value='Epoch 1'), FloatProgress(value=0.0, max=656.0), HTML(value='')))

# %%
# torch.save(gen.state_dict(), f'gen_pretrained_sn.pt')
gen.load_state_dict(torch.load('gen_pretrained.pt'))
# Out:
# <All keys matched successfully>

# %%
plot_sample(X_sample, y_sample, gen, 0)

# %% [markdown]
# ## GAN

# %%
trainer = GANTrainer(
    gen, disc, gen_optimizer, disc_optimizer, dl_train, disc_repeats=5, l_loss='l1', 
    adv_loss_type='Wasserstein', gp_lambda=10,
    l_lambda=5, plot=True, plotting_sample=(X_sample, y_sample)
)

# %%
trainer.fit(10)
# Out:
# HBox(children=(HTML(value='Epoch 1'), FloatProgress(value=0.0, max=656.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch 2'), FloatProgress(value=0.0, max=656.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch 3'), FloatProgress(value=0.0, max=656.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-2b917777f619> in <module>
# ----> 1 trainer.fit(10)
#
# ~/nwp-downscale/notebooks/Experiments/src/trainer.py in fit(self, epochs)
#     255                     if self.gp_lambda:
#     256                         epsilon = torch.rand(len(real), 1, 1, 1, device=device, requires_grad=True)
# --> 257                         gradient = get_gradient(self.disc, X, real, fake.detach(), epsilon)
#     258                         gp = gradient_penalty(gradient)
#     259                         disc_loss += self.gp_lambda * gp
#
# ~/nwp-downscale/notebooks/Experiments/src/trainer.py in get_gradient(crit, X, real, fake, epsilon)
#     116
#     117     # Calculate the critic's scores on the mixed images
# --> 118     mixed_scores = crit([X, mixed_images])
#     119
#     120     # Take the gradient of the scores with respect to the images
#
# /anaconda/envs/nwp-downscale/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/nwp-downscale/notebooks/Experiments/src/models.py in forward(self, x)
#     116             lr, hr = x
#     117             x = torch.cat([hr, self.upsample(lr)], dim=1)
# --> 118         out = self.downblocks(x)
#     119         out = self.resblocks(out)
#     120         out = out.mean([2, 3])  # Global average pooling
#
# /anaconda/envs/nwp-downscale/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /anaconda/envs/nwp-downscale/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# /anaconda/envs/nwp-downscale/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/nwp-downscale/notebooks/Experiments/src/layers.py in forward(self, x)
#      37         out = self.conv1(out)
#      38         out = self.activation2(out)
# ---> 39         out = self.conv2(out)
#      40         if hasattr(self, 'skip_conv'):
#      41             x = self.skip_conv(x)
#
# /anaconda/envs/nwp-downscale/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     522     def __call__(self, *input, **kwargs):
#     523         for hook in self._forward_pre_hooks.values():
# --> 524             result = hook(self, input)
#     525             if result is not None:
#     526                 if not isinstance(result, tuple):
#
# /anaconda/envs/nwp-downscale/lib/python3.8/site-packages/torch/nn/utils/spectral_norm.py in __call__(self, module, inputs)
#      97
#      98     def __call__(self, module, inputs):
# ---> 99         setattr(module, self.name, self.compute_weight(module, do_power_iteration=module.training))
#     100
#     101     def _solve_v_and_rescale(self, weight_mat, u, target_sigma):
#
# /anaconda/envs/nwp-downscale/lib/python3.8/site-packages/torch/nn/utils/spectral_norm.py in compute_weight(self, module, do_power_iteration)
#      80                 if self.n_power_iterations > 0:
#      81                     # See above on why we need to clone
# ---> 82                     u = u.clone(memory_format=torch.contiguous_format)
#      83                     v = v.clone(memory_format=torch.contiguous_format)
#      84
#
# KeyboardInterrupt:

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(10, 4))
ax1.plot(trainer.train_gen_losses); ax1.set_title('Generator loss')
ax2.plot(trainer.train_l_losses); ax2.set_title('L1 loss')
ax3.plot(trainer.train_disc_losses); ax3.set_title('Disc loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2afd30c4df98> in <module>
# ----> 1 fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(10, 4))
#       2 ax1.plot(trainer.train_gen_losses); ax1.set_title('Generator loss')
#       3 ax2.plot(trainer.train_l_losses); ax2.set_title('L1 loss')
#       4 ax3.plot(trainer.train_disc_losses); ax3.set_title('Disc loss')
#
# NameError: name 'plt' is not defined

# %%
# plt.plot(trainer.train_gen_losses, label='gen')
# plt.plot(trainer.train_l_losses, label='l_loss')
plt.plot(trainer.train_disc_losses, label='disc')
plt.legend()

# %%
X, y = next(iter(dl_train))
for i in range(5):
    plot_sample(X, y, gen, i)

# %%
X, y = next(iter(dl_valid))
for i in range(5):
    plot_sample(X, y, gen, i)

# %%
plt.hist(trainer.disc_preds_real[-1])
plt.hist(trainer.disc_preds_fake[-1])
plt.hist(trainer.gen_preds_fake[-1])
